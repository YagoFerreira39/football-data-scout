# %%
import pandas as pd

# %%
df = pd.read_csv("./data/Wyscout_League_Export.csv")

# %%
league_map = {

# ALBANIA
"Albania Superiore League": ("Kategoria Superiore", "Albania"),

# ARGENTINA
"Argentina Primera Division": ("Liga Profesional de Fútbol", "Argentina"),

# AUSTRALIA
"Australia A-League": ("A-League Men", "Australia"),

# AUSTRIA
"Austria Bundesliga": ("Austrian Bundesliga", "Austria"),

# BELGIUM
"Belgium First Division A": ("Belgian Pro League", "Belgium"),
"Belgium First Division B": ("Challenger Pro League", "Belgium"),

# BOLIVIA
"Bolivia Primera Division": ("División Profesional", "Bolivia"),

# BOSNIA
"Bosnia Premijer Liga": ("Premijer Liga", "Bosnia and Herzegovina"),

# BRAZIL
"Brazil Serie A": ("Campeonato Brasileiro Série A", "Brazil"),
"Brazil Serie B": ("Campeonato Brasileiro Série B", "Brazil"),

# BULGARIA
"Bulgaria First League": ("First Professional Football League", "Bulgaria"),

# CANADA
"Canada Premier League": ("Canadian Premier League", "Canada"),

# CHILE
"Chile Primera Division": ("Campeonato Nacional", "Chile"),

# CHINA
"China Super League": ("Chinese Super League", "China"),

# COLOMBIA
"Colombia Primera A": ("Categoría Primera A", "Colombia"),

# COSTA RICA
"Costa Rica Primera Division": ("Liga FPD", "Costa Rica"),

# CROATIA
"Croatia 1.HNL": ("SuperSport HNL", "Croatia"),

# CYPRUS
"Cyprus First Division": ("Cypriot First Division", "Cyprus"),

# CZECHIA
"Czech Fortuna Liga": ("Chance Liga", "Czech Republic"),

# DENMARK
"Denmark Superliga": ("Danish Superliga", "Denmark"),
"Denmark 1st Division": ("Danish 1st Division", "Denmark"),

# ECUADOR
"Ecuador Serie A": ("LigaPro Serie A", "Ecuador"),

# EGYPT
"Egypt Premier League": ("Egyptian Premier League", "Egypt"),

# ENGLAND
"England Premier League": ("Premier League", "England"),
"England Championship": ("EFL Championship", "England"),
"England League One": ("EFL League One", "England"),
"England League Two": ("EFL League Two", "England"),
"England National League": ("National League", "England"),
"England National League North South": ("National League North/South", "England"),

# ESTONIA
"Estonia Meistriliiga": ("Meistriliiga", "Estonia"),

# FINLAND
"Finland Veikkausliiga": ("Veikkausliiga", "Finland"),

# FRANCE
"France Ligue 1": ("Ligue 1", "France"),
"France Ligue 2": ("Ligue 2", "France"),
"France Championnat National": ("Championnat National", "France"),

# GEORGIA
"Georgia Erovnuli Liga": ("Erovnuli Liga", "Georgia"),

# GERMANY
"Germany Bundesliga": ("Bundesliga", "Germany"),
"Germany 2. Bundesliga": ("2. Bundesliga", "Germany"),
"Germany 3. Liga": ("3. Liga", "Germany"),

# GREECE
"Greece Super League": ("Super League Greece", "Greece"),

# HUNGARY
"Hungary NB1": ("Nemzeti Bajnokság I", "Hungary"),

# INDONESIA
"Indonesia Liga 1": ("Liga 1", "Indonesia"),

# IRELAND
"Ireland Premier Division": ("League of Ireland Premier Division", "Ireland"),
"Ireland First Division": ("League of Ireland First Division", "Ireland"),

# ISRAEL
"Israel Ligat Ha'Al": ("Ligat Ha'Al", "Israel"),

# ITALY
"Italy Serie A": ("Serie A", "Italy"),
"Italy Serie B": ("Serie B", "Italy"),
"Italy Campionato Primavera 1": ("Campionato Primavera 1", "Italy"),

# JAPAN
"Japan J1-League": ("J1 League", "Japan"),
"Japan J2-League": ("J2 League", "Japan"),

# KAZAKHSTAN
"Kazakhstan Premier League": ("Kazakhstan Premier League", "Kazakhstan"),

# KOREA
"Korea K-League 1": ("K League 1", "South Korea"),
"Korea K-League 2": ("K League 2", "South Korea"),

# LATVIA
"Latvia Virsliga": ("Virslīga", "Latvia"),

# MALAYSIA
"Malaysia Super League": ("Malaysia Super League", "Malaysia"),

# MEXICO
"Mexico Liga MX": ("Liga MX", "Mexico"),
"Mexico Liga de Expansion": ("Liga de Expansión MX", "Mexico"),

# MOROCCO
"Morocco Botola Pro": ("Botola Pro", "Morocco"),

# NETHERLANDS
"Netherlands Eredivisie": ("Eredivisie", "Netherlands"),
"Netherlands Eerste Divisie": ("Eerste Divisie", "Netherlands"),

# NORTHERN IRELAND
"Northern Ireland Premiership": ("NIFL Premiership", "Northern Ireland"),

# NORWAY
"Norway Eliteserien": ("Eliteserien", "Norway"),
"Norway First Division": ("OBOS-ligaen", "Norway"),

# PARAGUAY
"Paraguay Primera Division": ("División Profesional", "Paraguay"),

# PERU
"Peru Primera Division": ("Liga 1", "Peru"),

# POLAND
"Poland Ekstraklasa": ("Ekstraklasa", "Poland"),
"Poland 1 Liga": ("I liga", "Poland"),

# PORTUGAL
"Portugal Primeira Liga": ("Primeira Liga", "Portugal"),
"Portugal Segunda Liga": ("Liga Portugal 2", "Portugal"),

# ROMANIA
"Romania SuperLiga": ("SuperLiga", "Romania"),

# RUSSIA
"Russia Premier League": ("Russian Premier League", "Russia"),

# SCOTLAND
"Scotland Premiership": ("Scottish Premiership", "Scotland"),
"Scotland Championship": ("Scottish Championship", "Scotland"),
"Scotland League One": ("Scottish League One", "Scotland"),
"Scotland League Two": ("Scottish League Two", "Scotland"),

# SERBIA
"Serbia Super Liga": ("Serbian SuperLiga", "Serbia"),

# SLOVAKIA
"Slovakia Super Liga": ("Niké Liga", "Slovakia"),

# SLOVENIA
"Slovenia Prva Liga": ("PrvaLiga", "Slovenia"),

# SOUTH AFRICA
"South Africa PSL": ("Premier Soccer League", "South Africa"),

# SPAIN
"Spain La Liga": ("La Liga", "Spain"),
"Spain Segunda": ("LaLiga Hypermotion", "Spain"),
"Spain Primera Division RFEF": ("Primera Federación", "Spain"),

# SWEDEN
"Sweden Allsvenskan": ("Allsvenskan", "Sweden"),

# SWITZERLAND
"Switzerland Super League": ("Swiss Super League", "Switzerland"),
"Switzerland Challenge League": ("Swiss Challenge League", "Switzerland"),

# TURKEY
"Turkey Super Lig": ("Süper Lig", "Turkey"),

# UKRAINE
"Ukraine Premier League": ("Ukrainian Premier League", "Ukraine"),

# URUGUAY
"Uruguay Primera Division": ("Primera División", "Uruguay"),

# USA
"USA MLS": ("Major League Soccer", "USA"),
"USA MLS Next Pro": ("MLS Next Pro", "USA"),
"USA USL Championship": ("USL Championship", "USA"),

# UZBEKISTAN
"Uzbekistan Super League": ("Uzbek Super League", "Uzbekistan"),

# VENEZUELA
"Venezuela Primera Division": ("Primera División", "Venezuela"),
}

# %%
df.columns = (
    df.columns
    .str.lower()
    .str.replace(",", "")
    .str.replace(" ", "_")
)

df["league_base"] = df["league"].str.replace(r"\s\d{4}(-\d{2})?$", "", regex=True)
df["league_name"] = df["league_base"].map(lambda x: league_map.get(x, (None, None))[0])
df["league_country"] = df["league_base"].map(lambda x: league_map.get(x, (None, None))[1])
df["season"] = df["league"].str.extract(r"(\d{4}(?:-\d{2})?)$")

# %%
df.head()
# Out:
#              player              team team_within_selected_timeframe position  \
# 0      B. van Rooij            Twente                         Twente       RB
# 1           N. Olij  Sparta Rotterdam               Sparta Rotterdam       GK
# 2     F. de Keijzer          Heracles                       Heracles       GK
# 3  T. Didillon-Hödl         Willem II                      Willem II       GK
# 4          M. Deijl   Go Ahead Eagles                Go Ahead Eagles       RB
#
#     age  market_value contract_expires  matches_played  minutes_played  goals  \
# 0  24.0       2000000       30/06/2028              36            3486      1
# 1  29.0       4000000       30/06/2028              34            3396      0
# 2  25.0        500000       30/06/2027              34            3353      0
# 3  29.0        500000       30/06/2026              34            3353      0
# 4  27.0       1200000       30/06/2027              34            3337      4
#
# ...

# %%
# ARGENTINA
argentina_primera_division_25_df = df[df["league"] == "Argentina Primera Division 2025"].copy()
argentina_primera_division_26_df = df[df["league"] == "Argentina Primera Division 2026"].copy()

# BELGIUM
belgium_first_division_a_24_25_df = df[df["league"] == "Belgium First Division A 2024-25"].copy()
belgium_first_division_a_25_26_df = df[df["league"] == "Belgium First Division A 2025-26"].copy()

belgium_first_division_b_24_25_df = df[df["league"] == "Belgium First Division B 2024-25"].copy()
belgium_first_division_b_25_26_df = df[df["league"] == "Belgium First Division B 2025-26"].copy()

# BRAZIL
brazil_serie_a_25_df = df[df["league"] == "Brazil Serie A 2025"].copy()
brazil_serie_a_26_df = df[df["league"] == "Brazil Serie A 2026"].copy()

brazil_serie_b_25_df = df[df["league"] == "Brazil Serie B 2025"].copy()

# CROATIA
croatia_1_hnl_24_25_df = df[df["league"] == "Croatia 1.HNL 2024-25"].copy()
croatia_1_hnl_25_26_df = df[df["league"] == "Croatia 1.HNL 2025-26"].copy()

# DENMARK
denmark_1st_division_24_25_df = df[df["league"] == "Denmark 1st Division 2024-25"].copy()
denmark_1st_division_25_26_df = df[df["league"] == "Denmark 1st Division 2025-26"].copy()

denmark_superliga_24_25_df = df[df["league"] == "Denmark Superliga 2024-25"].copy()
denmark_superliga_25_26_df = df[df["league"] == "Denmark Superliga 2025-26"].copy()

# ENGLAND
england_championship_24_25_df = df[df["league"] == "England Championship 2024-25"].copy()
england_championship_25_26_df = df[df["league"] == "England Championship 2025-26"].copy()

england_league_one_24_25_df = df[df["league"] == "England League One 2024-25"].copy()
england_league_one_25_26_df = df[df["league"] == "England League One 2025-26"].copy()

england_league_two_24_25_df = df[df["league"] == "England League Two 2024-25"].copy()
england_league_two_25_26_df = df[df["league"] == "England League Two 2025-26"].copy()

england_national_league_24_25_df = df[df["league"] == "England National League 2024-25"].copy()
england_national_league_25_26_df = df[df["league"] == "England National League 2025-26"].copy()

england_national_league_north_south_24_25_df = df[df["league"] == "England National League North South 2024-25"].copy()
england_national_league_north_south_25_26_df = df[df["league"] == "England National League North South 2025-26"].copy()

premier_league_24_25_df = df[df["league"] == "England Premier League 2024-25"].copy()
premier_league_25_26_df = df[df["league"] == "England Premier League 2025-26"].copy()

# FRANCE
france_championnat_national_24_25_df = df[df["league"] == "France Championnat National 2024-25"].copy()
france_championnat_national_25_26_df = df[df["league"] == "France Championnat National 2025-26"].copy()

france_ligue_1_24_25_df = df[df["league"] == "France Ligue 1 2024-25"].copy()
france_ligue_1_25_26_df = df[df["league"] == "France Ligue 1 2025-26"].copy()

france_ligue_2_24_25_df = df[df["league"] == "France Ligue 2 2024-25"].copy()
france_ligue_2_25_26_df = df[df["league"] == "France Ligue 2 2025-26"].copy()

# GERMANY
germany_2_bundesliga_24_25_df = df[df["league"] == "Germany 2. Bundesliga 2024-25"].copy()
germany_2_bundesliga_25_26_df = df[df["league"] == "Germany 2. Bundesliga 2025-26"].copy()

germany_3_liga_24_25_df = df[df["league"] == "Germany 3. Liga 2024-25"].copy()
germany_3_liga_25_26_df = df[df["league"] == "Germany 3. Liga 2025-26"].copy()

germany_bundesliga_24_25_df = df[df["league"] == "Germany Bundesliga 2024-25"].copy()
germany_bundesliga_25_26_df = df[df["league"] == "Germany Bundesliga 2025-26"].copy()

# ITALY
italy_campionato_primavera_1_24_25_df = df[df["league"] == "Italy Campionato Primavera 1 2024-25"].copy()
italy_campionato_primavera_1_25_26_df = df[df["league"] == "Italy Campionato Primavera 1 2025-26"].copy()

italy_serie_a_24_25_df = df[df["league"] == "Italy Serie A 2024-25"].copy()
italy_serie_a_25_26_df = df[df["league"] == "Italy Serie A 2025-26"].copy()

italy_serie_b_24_25_df = df[df["league"] == "Italy Serie B 2024-25"].copy()
italy_serie_b_25_26_df = df[df["league"] == "Italy Serie B 2025-26"].copy()

# MEXICO
mexico_liga_de_expansion_24_25_df = df[df["league"] == "Mexico Liga de Expansion 2024-25"].copy()
mexico_liga_de_expansion_25_26_df = df[df["league"] == "Mexico Liga de Expansion 2025-26"].copy()

mexico_liga_mx_24_25_df = df[df["league"] == "Mexico Liga MX 2024-25"].copy()
mexico_liga_mx_25_26_df = df[df["league"] == "Mexico Liga MX 2025-26"].copy()

# NETHERLANDS
netherlands_eerste_divisie_24_25_df = df[df["league"] == "Netherlands Eerste Divisie 2024-25"].copy()
netherlands_eerste_divisie_25_26_df = df[df["league"] == "Netherlands Eerste Divisie 2025-26"].copy()

netherlands_eredivisie_24_25_df = df[df["league"] == "Netherlands Eredivisie 2024-25"].copy()
netherlands_eredivisie_25_26_df = df[df["league"] == "Netherlands Eredivisie 2025-26"].copy()

# NORWAY
norway_eliteserien_25_df = df[df["league"] == "Norway Eliteserien 2025"].copy()
norway_first_division_25_df = df[df["league"] == "Norway First Division 2025"].copy()

# PARAGUAY
paraguay_primera_division_25_df = df[df["league"] == "Paraguay Primera Division 2025"].copy()
paraguay_primera_division_26_df = df[df["league"] == "Paraguay Primera Division 2026"].copy()

# POLAND
poland_1_liga_24_25_df = df[df["league"] == "Poland 1 Liga 2024-25"].copy()
poland_1_liga_25_26_df = df[df["league"] == "Poland 1 Liga 2025-26"].copy()

poland_ekstraklasa_24_25_df = df[df["league"] == "Poland Ekstraklasa 2024-25"].copy()
poland_ekstraklasa_25_26_df = df[df["league"] == "Poland Ekstraklasa 2025-26"].copy()

# PORTUGAL
portugal_primeira_liga_24_25_df = df[df["league"] == "Portugal Primeira Liga 2024-25"].copy()
portugal_primeira_liga_25_26_df = df[df["league"] == "Portugal Primeira Liga 2025-26"].copy()

portugal_segunda_liga_24_25_df = df[df["league"] == "Portugal Segunda Liga 2024-25"].copy()
portugal_segunda_liga_25_26_df = df[df["league"] == "Portugal Segunda Liga 2025-26"].copy()

# SCOTLAND
scotland_championship_24_25_df = df[df["league"] == "Scotland Championship 2024-25"].copy()
scotland_championship_25_26_df = df[df["league"] == "Scotland Championship 2025-26"].copy()

scotland_league_one_24_25_df = df[df["league"] == "Scotland League One 2024-25"].copy()
scotland_league_one_25_26_df = df[df["league"] == "Scotland League One 2025-26"].copy()

scotland_league_two_24_25_df = df[df["league"] == "Scotland League Two 2024-25"].copy()
scotland_league_two_25_26_df = df[df["league"] == "Scotland League Two 2025-26"].copy()

scotland_premiership_24_25_df = df[df["league"] == "Scotland Premiership 2024-25"].copy()
scotland_premiership_25_26_df = df[df["league"] == "Scotland Premiership 2025-26"].copy()

# SERBIA
serbia_super_liga_24_25_df = df[df["league"] == "Serbia Super Liga 2024-25"].copy()
serbia_super_liga_25_26_df = df[df["league"] == "Serbia Super Liga 2025-26"].copy()

# SPAIN
spain_la_liga_24_25_df = df[df["league"] == "Spain La Liga 2024-25"].copy()
spain_la_liga_25_26_df = df[df["league"] == "Spain La Liga 2025-26"].copy()

spain_primera_division_rfef_24_25_df = df[df["league"] == "Spain Primera Division RFEF 2024-25"].copy()
spain_primera_division_rfef_25_26_df = df[df["league"] == "Spain Primera Division RFEF 2025-26"].copy()

spain_segunda_24_25_df = df[df["league"] == "Spain Segunda 2024-25"].copy()
spain_segunda_25_26_df = df[df["league"] == "Spain Segunda 2025-26"].copy()

# SWEDEN
sweden_allsvenskan_25_df = df[df["league"] == "Sweden Allsvenskan 2025"].copy()

# TURKEY
turkey_super_lig_24_25_df = df[df["league"] == "Turkey Super Lig 2024-25"].copy()
turkey_super_lig_25_26_df = df[df["league"] == "Turkey Super Lig 2025-26"].copy()

# URUGUAY
uruguay_primera_division_25_df = df[df["league"] == "Uruguay Primera Division 2025"].copy()
uruguay_primera_division_26_df = df[df["league"] == "Uruguay Primera Division 2026"].copy()

# USA
usa_mls_25_df = df[df["league"] == "USA MLS 2025"].copy()
usa_mls_next_pro_25_df = df[df["league"] == "USA MLS Next Pro 2025"].copy()
usa_usl_championship_25_df = df[df["league"] == "USA USL Championship 2025"].copy()
